# %% [markdown]
# # Conditional Based Operations - Pt 1

# %%
import numpy as np

# %%
arr = np.array([10, 25, 30, 45, 50, 15])
arr
# Out:
# array([10, 25, 30, 45, 50, 15])

# %%
condition = arr > 20
condition
# Out:
# array([False,  True,  True,  True,  True, False])

# %%
result = arr[(arr < 20) | (arr > 40)]
result
# Out:
# array([10, 45, 50, 15])
