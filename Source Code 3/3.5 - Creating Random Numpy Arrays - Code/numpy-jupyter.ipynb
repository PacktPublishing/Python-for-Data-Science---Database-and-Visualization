# %% [markdown]
# # Random NumPy Arrays

# %%
import numpy as np

# %%
arr = np.random.rand(3,2)
arr
# Out:
# array([[0.24180408, 0.81785374],
#        [0.93995116, 0.17113616],
#        [0.42956766, 0.64381911]])

# %%
arr = np.random.randint(5,20)
arr
# Out:
# 12
