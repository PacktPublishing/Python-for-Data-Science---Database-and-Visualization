# %% [markdown]
# # Repeat & Tile in NumPy Arrays

# %%
import numpy as np

# %%
arr = np.array([1, 2, 3])
arr
# Out:
# array([1, 2, 3])

# %%
arr_repeat = np.repeat(arr, [2, 3, 1])
arr_repeat
# Out:
# array([1, 1, 2, 2, 2, 3])

# %%
arr_tile = np.tile(arr, 2)
arr_tile
# Out:
# array([1, 2, 3, 1, 2, 3])

# %%
arr = np.array([0,1])
matrix = np.tile(arr, (3,2))
matrix
