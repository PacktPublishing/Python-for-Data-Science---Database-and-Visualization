# %% [markdown]
# # Vectorization in Arrays

# %%
import numpy as np

# %%
arr = np.array([1, 3, 6, 10, 15, 21])
arr
# Out:
# array([ 1,  3,  6, 10, 15, 21])

# %%
res = arr + 10
res
# Out:
# array([11, 13, 16, 20, 25, 31])

# %%
def arr_square(x):
    return x*x
sq_fun = np.vectorize(arr_square)

# %%
sq_fun(arr)
# Out:
# array([  1,   9,  36, 100, 225, 441])
