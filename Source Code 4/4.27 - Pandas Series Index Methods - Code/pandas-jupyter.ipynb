# %%
import pandas as pd

# %%
s = pd.Series(
    [1500, 800, 3500, 12000, 450],
    index=["Keyboard", "Mouse", "Tablet", "Laptop", "USB Hub"]
)
s
# Out:
# Keyboard     1500
# Mouse         800
# Tablet       3500
# Laptop      12000
# USB Hub       450
# dtype: int64

# %%
s.rename({"USB Hub": "USB", "Laptop": "Notebook"})
# Out:
# Keyboard     1500
# Mouse         800
# Tablet       3500
# Notebook    12000
# USB           450
# dtype: int64

# %%
s
# Out:
# Keyboard     1500
# Mouse         800
# Tablet       3500
# Laptop      12000
# USB Hub       450
# dtype: int64

# %%
s.sort_index(ascending=False)
# Out:
# USB Hub       450
# Tablet       3500
# Mouse         800
# Laptop      12000
# Keyboard     1500
# dtype: int64

# %%
s.sort_values(ascending=False)
# Out:
# Laptop      12000
# Tablet       3500
# Keyboard     1500
# Mouse         800
# USB Hub       450
# dtype: int64

# %%
s_sorted = s.sort_values()
s_sorted.reset_index()
# Out:
#       index      0
# 0   USB Hub    450
# 1     Mouse    800
# 2  Keyboard   1500
# 3    Tablet   3500
# 4    Laptop  12000

# %%
s_sorted.reset_index(drop=True)
