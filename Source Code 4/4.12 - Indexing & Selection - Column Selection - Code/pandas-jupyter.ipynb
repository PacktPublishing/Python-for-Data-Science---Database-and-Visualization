# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
   "OrderID":  ["O_001", "O_002", "O_003", "O_004", "O_005",
                "O_006", "O_007", "O_008", "O_009", "O_010"],
   "Customer": ["Cust_A", "Cust_B", "Cust_C", "Cust_D", "Cust_E",
                "Cust_F", "Cust_G", "Cust_H", "Cust_I", "Cust_J"],
   "Product":  ["Laptop", "Mouse", "Keyboard", "Monitor", "Webcam",
                "Headset", "Laptop", "Mouse", "Monitor", "Keyboard"],
   "Amount":   [45000, 800, 1500, 12000, 2500,
                3500, 47000, 750, 11500, 1400],
   "Status":   ["Delivered", "Pending", "Delivered", "Shipped", "Delivered",
                "Pending", "Delivered", "Shipped", "Delivered", "Pending"]
})
df
# Out:
#   OrderID Customer   Product  Amount     Status
# 0   O_001   Cust_A    Laptop   45000  Delivered
# 1   O_002   Cust_B     Mouse     800    Pending
# 2   O_003   Cust_C  Keyboard    1500  Delivered
# 3   O_004   Cust_D   Monitor   12000    Shipped
# 4   O_005   Cust_E    Webcam    2500  Delivered
# 5   O_006   Cust_F   Headset    3500    Pending
# 6   O_007   Cust_G    Laptop   47000  Delivered
# 7   O_008   Cust_H     Mouse     750    Shipped
# 8   O_009   Cust_I   Monitor   11500  Delivered
# 9   O_010   Cust_J  Keyboard    1400    Pending

# %%
df["Customer"]
# Out:
# 0    Cust_A
# 1    Cust_B
# 2    Cust_C
# 3    Cust_D
# 4    Cust_E
# 5    Cust_F
# 6    Cust_G
# 7    Cust_H
# 8    Cust_I
# 9    Cust_J
# Name: Customer, dtype: str

# %%
df[["Customer", "Amount"]]
# Out:
#   Customer  Amount
# 0   Cust_A   45000
# 1   Cust_B     800
# 2   Cust_C    1500
# 3   Cust_D   12000
# 4   Cust_E    2500
# 5   Cust_F    3500
# 6   Cust_G   47000
# 7   Cust_H     750
# 8   Cust_I   11500
# 9   Cust_J    1400

# %%
df[["Amount", "Status", "Customer"]]
# Out:
#    Amount     Status Customer
# 0   45000  Delivered   Cust_A
# 1     800    Pending   Cust_B
# 2    1500  Delivered   Cust_C
# 3   12000    Shipped   Cust_D
# 4    2500  Delivered   Cust_E
# 5    3500    Pending   Cust_F
# 6   47000  Delivered   Cust_G
# 7     750    Shipped   Cust_H
# 8   11500  Delivered   Cust_I
# 9    1400    Pending   Cust_J

# %%
df['Customer']
#%%
df[["Customer", "Amount"]]
#%%
df[["Amount", "Status", "Customer"]]
