# %%
import pandas as pd
import numpy as np

# %%
arr = np.array([1500, 800, 3500, 12000, 450], dtype=float)
arr
# Out:
# array([ 1500.,   800.,  3500., 12000.,   450.])

# %%
s = pd.Series(arr, 
              dtype="float32",
              index=["Keyboard", "Mouse", "Tablet", "Laptop", "USB Hub"])
s
# Out:
# Keyboard     2300.0
# Mouse         800.0
# Tablet       3500.0
# Laptop      12000.0
# USB Hub       450.0
# dtype: float32

# %%
arr[0] = 2300
