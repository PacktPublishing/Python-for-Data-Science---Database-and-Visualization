# %%
import pandas as pd

# %%
df1 = pd.DataFrame({
    "OrderID": ["O_001", "O_002", "O_003"],
    "Product": ["Laptop Pro", "Wireless Mouse", "4K Monitor"],
    "Amount": [45000, 800, 18000]
})

df2 = pd.DataFrame({
    "OrderID": ["O_004", "O_005", "O_006"],
    "Product": ["HD Webcam", "Gaming Laptop", "USB Keyboard"],
    "Amount": [2500, 47000, 1400],
    "Status": ["Delivered", "Pending", "Shipped"]
})

# %%
pd.concat([df1, df2], axis=1)
# Out:
#   OrderID         Product  Amount OrderID        Product  Amount     Status
# 0   O_001      Laptop Pro   45000   O_004      HD Webcam    2500  Delivered
# 1   O_002  Wireless Mouse     800   O_005  Gaming Laptop   47000    Pending
# 2   O_003      4K Monitor   18000   O_006   USB Keyboard    1400    Shipped
