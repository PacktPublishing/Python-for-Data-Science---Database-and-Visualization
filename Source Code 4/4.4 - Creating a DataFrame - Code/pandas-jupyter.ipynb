# %%
import pandas as pd

# %%
df = pd.DataFrame(["This", "is", "a", "test", "string"])
print(df)
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/xx/yp5lz5wx36s8mz9_krf3gf380000gn/T/ipykernel_64850/204954781.py in ?()
# ----> 1 df = pd.DataFrame(10)
#       2 print(df)
#       3 print(df.shape)
#
# ~/Projects/DataScience/.venv/lib/python3.14/site-packages/pandas/core/frame.py in ?(self, data, index, columns, dtype, copy)
#     865                 )
#     866         # For data is scalar
#     867         else:
#     868             if index is None or columns is None:
# --> 869                 raise ValueError("DataFrame constructor not properly called!")
#     870
#     871             index = ensure_index(index)
#     872             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
