# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50], index=["Num_1", "Num_2", "Num_3", "Num_4", "Num_5"])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(s.name)
# Out:
# None

# %%
s.name = "Numbers"
print(s.name)
s
# Out:
# Numbers
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Numbers, dtype: int64
