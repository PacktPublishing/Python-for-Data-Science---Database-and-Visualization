# %%
import pandas as pd

# %%
data = {
    "Product": ["Laptop", "Mouse", "Keyboard", "Monitor"],
    "Price": [45000, 800, 1500, 12000],
    "Stock": [15, 50, 30, 20]
}

# %%
df = pd.DataFrame(data, index=["P001", "P002", "P003", "P004"])
df
# Out:
#        Product  Price  Stock
# P001    Laptop  45000     15
# P002     Mouse    800     50
# P003  Keyboard   1500     30
# P004   Monitor  12000     20

# %%
print(df.columns)
# Out:
# Index(['Product', 'Price', 'Stock'], dtype='str')

# %%
print(len(df.columns))
# Out:
# 3

# %%
print(df.index)
# Out:
# Index(['P001', 'P002', 'P003', 'P004'], dtype='str')

# %%
print(len(df.index))
# Out:
# 4
