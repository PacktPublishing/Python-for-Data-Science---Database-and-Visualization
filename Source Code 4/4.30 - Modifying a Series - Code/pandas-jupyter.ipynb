# %%
import pandas as pd

# %%
fruit_weights = {
    "Apple": 182,
    "Banana": 118,
    "Orange": 131,
    "Mango": 202,
    "Strawberry": 12,
    "Grapes": 5,
    "Pineapple": 905,
    "Watermelon": 4520,
    "Kiwi": 69,
    "Blueberry": 2
}
s = pd.Series(fruit_weights, name="Weight(in grams)")
s
# Out:
# Apple          182
# Banana         118
# Orange         131
# Mango          202
# Strawberry      12
# Grapes           5
# Pineapple      905
# Watermelon    4520
# Kiwi            69
# Blueberry        2
# Name: Weight(in grams), dtype: int64

# %%
s["Apple"] = 195
s
# Out:
# Apple          195
# Banana         118
# Orange         131
# Mango          202
# Strawberry      12
# Grapes           5
# Pineapple      905
# Watermelon    4520
# Kiwi            69
# Blueberry        2
# Name: Weight(in grams), dtype: int64

# %%
s.loc["Banana"] = 125
s
# Out:
# Apple          195
# Banana         125
# Orange         131
# Mango          202
# Strawberry      12
# Grapes           5
# Pineapple      905
# Watermelon    4520
# Kiwi            69
# Blueberry        2
# Name: Weight(in grams), dtype: int64

# %%
s[["Grapes", "Blueberry"]] = [8, 4]
s
# Out:
# Apple          195
# Banana         125
# Orange         131
# Mango          202
# Strawberry      12
# Grapes           8
# Pineapple      905
# Watermelon    4520
# Kiwi            69
# Blueberry        4
# Name: Weight(in grams), dtype: int64

# %%
s["Papaya"] = 300
s
# Out:
# Apple          195
# Banana         125
# Orange         131
# Mango          202
# Strawberry      12
# Grapes           8
# Pineapple      905
# Watermelon    4520
# Kiwi            69
# Blueberry        4
# Papaya         300
# Name: Weight(in grams), dtype: int64

# %%
s = s.drop("Watermelon")
s
# Out:
# Apple         195
# Banana        125
# Orange        131
# Mango         202
# Strawberry     12
# Grapes          8
# Pineapple     905
# Kiwi           69
# Blueberry       4
# Papaya        300
# Name: Weight(in grams), dtype: int64
