# %%
import pandas as pd

# %%
s = pd.Series(
    [1500,800,3500,12000,450],
    index=["Keyboard", "Mouse", "Tablet", "Laptop", "USB Hub"]
)
s
# Out:
# Keyboard     1500
# Mouse         800
# Tablet       3500
# Laptop      12000
# USB Hub       450
# dtype: int64

# %%
s[0:3]
# Out:
# Keyboard    1500
# Mouse        800
# Tablet      3500
# dtype: int64

# %%
s['Laptop']
# Out:
# np.int64(12000)

# %%
s.iloc[2]
# Out:
# np.int64(3500)

# %%
s.iloc[1:4]
# Out:
# Mouse       800
# Tablet     3500
# Laptop    12000
# dtype: int64

# %%
s.iloc[-1]
# Out:
# np.int64(450)

# %%
s.loc["Mouse"]
# Out:
# np.int64(800)

# %%
s.loc["Mouse":"Laptop"]
# Out:
# Mouse       800
# Tablet     3500
# Laptop    12000
# dtype: int64

# %%
s.loc[["Keyboard", "Laptop", "USB Hub"]]
# Out:
# Keyboard     1500
# Laptop      12000
# USB Hub       450
# dtype: int64

# %%
s.iloc[[0,3,4]]
