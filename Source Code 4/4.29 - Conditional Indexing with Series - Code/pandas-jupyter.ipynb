# %%
import pandas as pd

# %%
fruit_weights = {
    "Apple": 182,
    "Banana": 118,
    "Orange": 131,
    "Mango": 202,
    "Strawberry": 12,
    "Grapes": 5,
    "Pineapple": 905,
    "Watermelon": 4520,
    "Kiwi": 69,
    "Blueberry": 2
}

# %%
s = pd.Series(fruit_weights, name="Weight(in grams)")
s
# Out:
# Apple          182
# Banana         118
# Orange         131
# Mango          202
# Strawberry      12
# Grapes           5
# Pineapple      905
# Watermelon    4520
# Kiwi            69
# Blueberry        2
# Name: Weight(in grams), dtype: int64

# %%
s>100
# Out:
# Apple          True
# Banana         True
# Orange         True
# Mango          True
# Strawberry    False
# Grapes        False
# Pineapple      True
# Watermelon     True
# Kiwi          False
# Blueberry     False
# Name: Weight(in grams), dtype: bool

# %%
s[s > 100]
# Out:
# Apple          182
# Banana         118
# Orange         131
# Mango          202
# Pineapple      905
# Watermelon    4520
# Name: Weight(in grams), dtype: int64

# %%
s[(s > 100) & (s <= 905)]
# Out:
# Apple        182
# Banana       118
# Orange       131
# Mango        202
# Pineapple    905
# Name: Weight(in grams), dtype: int64

# %%
s[(s < 100) | (s > 905)]
# Out:
# Strawberry      12
# Grapes           5
# Watermelon    4520
# Kiwi            69
# Blueberry        2
# Name: Weight(in grams), dtype: int64

# %%
s[~(s < 200)]
