# %%
import pandas as pd
import numpy as np

# %%
arr = np.array([101, 205, 310, 450, 530])
df = pd.DataFrame(arr, columns=["Score"],
                 index=["S01", "S02", "S03", "S04", "S05"])
df
# Out:
#      Score
# S01    101
# S02    205
# S03    310
# S04    450
# S05    530

# %%
scores = np.array([
    [85, 90, 78],
    [92, 88, 95],
    [78, 85, 82],
    [88, 92, 90]
])

# %%
df = pd.DataFrame(scores, columns=["Math", "Science", "English"],
                  index=["Stu_A", "Stu_B", "Stu_C", "Stu_D"])
print(df)
print()
print("Shape:", df.shape)
# Out:
#        Math  Science  English
# Stu_A    85       90       78
# Stu_B    92       88       95
# Stu_C    78       85       82
# Stu_D    88       92       90
#
# Shape: (4, 3)

# %%
print(df.dtypes)
# Out:
# Math       int64
# Science    int64
# English    int64
# dtype: object
